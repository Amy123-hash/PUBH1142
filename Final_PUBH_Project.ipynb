# %%
from IPython.core.display import display, HTML

# Display the text in large, blue font
display(HTML('<h1 style="color:darkblue; font-size: 36px;">Afrah Beshir PUBH_1142 Project </h1>'))
# Out:
# <h1 style="color:darkblue; font-size: 36px;">Afrah Beshir PUBH_1142 Project </h1>

# %%
display(HTML('<h1 style="color:blue; font-size: 33px;">Explanation of the Project:</h1>'))
# Out:
# <h1 style="color:blue; font-size: 33px;">Explanation of the Project:</h1>

# %%
# Displaying the section title for dataset introduction
display(HTML('<h1 style="color:lightblue; font-size: 30px;"> Dataset: Life Expectancy at Birth Across the Globe</h1>'))
# Out:
# <h1 style="color:lightblue; font-size: 30px;"> Dataset: Life Expectancy at Birth Across the Globe</h1>

# %% [markdown]
# ### This project looks into global trends in life expectancy at birth, as well as socio-economic and healthcare factors that influence disparities across different countries and regions. The dataset includes indicators such as GDP, immunization rates, and health expenditures. By using statistics, to find significant patterns and correlations that impact life expectancy worldwide.

# %% [markdown]
# ## Data Source & Credit
#
# The dataset used in this project is titled **"Life Expectancy at Birth Across the Globe"**, originally shared by [Sourav Banerjee](https://www.kaggle.com/datasets/souravbanerjee/life-expectancy-at-birth-across-the-globe) on Kaggle (last updated 10 months ago).
#
# ### Dataset Overview:
# This dataset explores **life expectancy at birth** globally, spanning from 1990 to 2021. It includes key variables such as:
# - ISO3 country codes
# - Country and Continent
# - Hemisphere
# - Human Development Groups
# - UNDP Developing Regions
# - HDI Rank (2021)
# - Life Expectancy at Birth (1990–2021)
#
# ###  Context:
# Life expectancy is a crucial indicator of population health and is influenced by healthcare quality, socioeconomic factors, and living conditions. This dataset helps illuminate disparities across countries and regions, offering insights into global longevity patterns.
#
# **Source:** [Kaggle – Life Expectancy at Birth Across the Globe](https://www.kaggle.com/datasets/souravbanerjee/life-expectancy-at-birth-across-the-globe)

# %% [markdown]
# ##**DATA WRANGLING**

# %% [markdown]
# ##Package import

# %%
#Imports NumPy and Pandas, essential libraries for data manipulation.
import numpy as np
import pandas as pd

# %% [markdown]
# ##Import Data

# %%
# Load the dataset
file_path = '/content/Life Expectancy at Birth.csv'  # Ensure this file is in the correct directory
life_expectancy_df = pd.read_csv(file_path)

# %%
df = pd.read_csv("/content/Life Expectancy at Birth.csv")

# %%
df.head()
#function is a method function that is already applied
# Out:
#   ISO3               Country Continent           Hemisphere  \
# 0  AFG           Afghanistan      Asia  Northern Hemisphere
# 1  AGO                Angola    Africa  Southern Hemisphere
# 2  ALB               Albania    Europe  Northern Hemisphere
# 3  AND               Andorra    Europe  Northern Hemisphere
# 4  ARE  United Arab Emirates      Asia  Northern Hemisphere
#
#   Human Development Groups UNDP Developing Regions  HDI Rank (2021)  \
# 0                      Low                      SA            180.0
# 1                   Medium                     SSA            148.0
# 2                     High                     ECA             67.0
# 3                Very High                     NaN             40.0
# 4                Very High                      AS             26.0
#
#    Life Expectancy at Birth (1990)  Life Expectancy at Birth (1991)  \
# 0                          45.9672                          46.6631
# ...

# %%
print(df.head())  # Show the first five rows
print(df.columns)  # Show all column names
print(df.info())  # Show dataset structure
# Out:
#   ISO3               Country Continent           Hemisphere  \
# 0  AFG           Afghanistan      Asia  Northern Hemisphere
# 1  AGO                Angola    Africa  Southern Hemisphere
# 2  ALB               Albania    Europe  Northern Hemisphere
# 3  AND               Andorra    Europe  Northern Hemisphere
# 4  ARE  United Arab Emirates      Asia  Northern Hemisphere
#
#   Human Development Groups UNDP Developing Regions  HDI Rank (2021)  \
# 0                      Low                      SA            180.0
# 1                   Medium                     SSA            148.0
# 2                     High                     ECA             67.0
# 3                Very High                     NaN             40.0
# 4                Very High                      AS             26.0
#
#    Life Expectancy at Birth (1990)  Life Expectancy at Birth (1991)  \
# 0                          45.9672                          46.6631
# ...

# %% [markdown]
#  Basic exploratory steps to understand the dataset contents and data types.

# %%
# Drop missing values to simplify analysis
life_expectancy_df.dropna(inplace=True)
# Compute summary statistics (mean, max, and median) for each numerical column
summary_statistics = life_expectancy_df.describe().T  # Transpose for readability

# Select only numerical columns for median calculation
numerical_cols = life_expectancy_df.select_dtypes(include=np.number).columns
summary_statistics['median'] = life_expectancy_df[numerical_cols].median()
summary_statistics['max'] = life_expectancy_df[numerical_cols].max()

# %% [markdown]
#  Cleans the data (removes NaNs) and summarizes numerical features with additional metrics (median, max).

# %%
#Show the "Contienent" colum
df['Continent']
# Out:
# 0         Asia
# 1       Africa
# 2       Europe
# 3       Europe
# 4         Asia
#         ...
# 190    Oceania
# 191       Asia
# 192     Africa
# 193     Africa
# 194     Africa
# Name: Continent, Length: 195, dtype: object

# %% [markdown]
# Navigating the DataFrame with .iloc and .loc to inspect rows and columns.

# %%
df.Country
# Out:
# 0               Afghanistan
# 1                    Angola
# 2                   Albania
# 3                   Andorra
# 4      United Arab Emirates
#                ...
# 190                   Samoa
# 191                   Yemen
# 192            South Africa
# 193                  Zambia
# 194                Zimbabwe
# Name: Country, Length: 195, dtype: object

# %%
df.Continent.unique()
# Out:
# array(['Asia', 'Africa', 'Europe', 'America', 'Oceania'], dtype=object)

# %%
df.iloc[0]
#this is a locator
#gives the first row of the data
# Out:
# ISO3                                               AFG
# Country                                    Afghanistan
# Continent                                         Asia
# Hemisphere                         Northern Hemisphere
# Human Development Groups                           Low
# UNDP Developing Regions                             SA
# HDI Rank (2021)                                  180.0
# Life Expectancy at Birth (1990)                45.9672
# Life Expectancy at Birth (1991)                46.6631
# Life Expectancy at Birth (1992)                47.5955
# Life Expectancy at Birth (1993)                51.4664
# Life Expectancy at Birth (1994)                51.4945
# Life Expectancy at Birth (1995)                52.5442
# Life Expectancy at Birth (1996)                53.2433
# Life Expectancy at Birth (1997)                53.6342
# Life Expectancy at Birth (1998)                52.9431
# Life Expectancy at Birth (1999)                54.8464
# ...

# %%
row, col = df.shape

# %%
df.iloc[0:5]
#row 0-5
# Out:
#   ISO3               Country Continent           Hemisphere  \
# 0  AFG           Afghanistan      Asia  Northern Hemisphere
# 1  AGO                Angola    Africa  Southern Hemisphere
# 2  ALB               Albania    Europe  Northern Hemisphere
# 3  AND               Andorra    Europe  Northern Hemisphere
# 4  ARE  United Arab Emirates      Asia  Northern Hemisphere
#
#   Human Development Groups UNDP Developing Regions  HDI Rank (2021)  \
# 0                      Low                      SA            180.0
# 1                   Medium                     SSA            148.0
# 2                     High                     ECA             67.0
# 3                Very High                     NaN             40.0
# 4                Very High                      AS             26.0
#
#    Life Expectancy at Birth (1990)  Life Expectancy at Birth (1991)  \
# 0                          45.9672                          46.6631
# ...

# %%
df.iloc[10]
# Out:
# ISO3                                               AZE
# Country                                     Azerbaijan
# Continent                                         Asia
# Hemisphere                         Northern Hemisphere
# Human Development Groups                          High
# UNDP Developing Regions                            ECA
# HDI Rank (2021)                                   91.0
# Life Expectancy at Birth (1990)                62.3522
# Life Expectancy at Birth (1991)                62.0524
# Life Expectancy at Birth (1992)                61.2956
# Life Expectancy at Birth (1993)                61.2856
# Life Expectancy at Birth (1994)                61.5941
# Life Expectancy at Birth (1995)                62.3052
# Life Expectancy at Birth (1996)                62.6217
# Life Expectancy at Birth (1997)                62.9728
# Life Expectancy at Birth (1998)                63.5609
# Life Expectancy at Birth (1999)                64.1892
# ...

# %%
df.iloc[0:5, 0:2]
# Out:
#   ISO3               Country
# 0  AFG           Afghanistan
# 1  AGO                Angola
# 2  ALB               Albania
# 3  AND               Andorra
# 4  ARE  United Arab Emirates

# %%
df.loc[0:5, 'Country']
# Out:
# 0             Afghanistan
# 1                  Angola
# 2                 Albania
# 3                 Andorra
# 4    United Arab Emirates
# 5               Argentina
# Name: Country, dtype: object

# %%
df.loc[0:5, 'Country':'Continent']
# Out:
#                 Country Continent
# 0           Afghanistan      Asia
# 1                Angola    Africa
# 2               Albania    Europe
# 3               Andorra    Europe
# 4  United Arab Emirates      Asia
# 5             Argentina   America

# %%
df.loc[0:5, 'Continent']
# Out:
# 0       Asia
# 1     Africa
# 2     Europe
# 3     Europe
# 4       Asia
# 5    America
# Name: Continent, dtype: object

# %% [markdown]
# More slicing to explore specific parts of the data.

# %%
Continent = df.Continent

# %%
Continent
# Out:
# 0         Asia
# 1       Africa
# 2       Europe
# 3       Europe
# 4         Asia
#         ...
# 190    Oceania
# 191       Asia
# 192     Africa
# 193     Africa
# 194     Africa
# Name: Continent, Length: 195, dtype: object

# %%
#numpy array of continent
Continent.values
# Out:
# array(['Asia', 'Africa', 'Europe', 'Europe', 'Asia', 'America', 'Asia',
#        'America', 'Oceania', 'Europe', 'Asia', 'Africa', 'Europe',
#        'Africa', 'Africa', 'Asia', 'Europe', 'Asia', 'America', 'Europe',
#        'Europe', 'America', 'America', 'America', 'America', 'Asia',
#        'Asia', 'Africa', 'Africa', 'America', 'Europe', 'America', 'Asia',
#        'Africa', 'Africa', 'Africa', 'Africa', 'America', 'Africa',
#        'Africa', 'America', 'America', 'Asia', 'Europe', 'Europe',
#        'Africa', 'America', 'Europe', 'America', 'Africa', 'America',
#        'Africa', 'Africa', 'Europe', 'Europe', 'Africa', 'Europe',
#        'Oceania', 'Europe', 'Oceania', 'Africa', 'Europe', 'Asia',
#        'Africa', 'Africa', 'Africa', 'Africa', 'Africa', 'Europe',
#        'America', 'America', 'America', 'Asia', 'America', 'Europe',
#        'America', 'Europe', 'Asia', 'Asia', 'Europe', 'Asia', 'Asia',
#        'Europe', 'Asia', 'Europe', 'America', 'Asia', 'Asia', 'Asia',
# ...

# %%
# tell me the unique elements in ""
df.Continent.unique()
# Out:
# array(['Asia', 'Africa', 'Europe', 'America', 'Oceania'], dtype=object)

# %%
Country = df.Country

# %%
Country
# Out:
# 0               Afghanistan
# 1                    Angola
# 2                   Albania
# 3                   Andorra
# 4      United Arab Emirates
#                ...
# 190                   Samoa
# 191                   Yemen
# 192            South Africa
# 193                  Zambia
# 194                Zimbabwe
# Name: Country, Length: 195, dtype: object

# %% [markdown]
# #Statistical Data for each Columns

# %%
# Display computed statistics
print("\nSummary Statistics:")
print(summary_statistics[['mean', 'max', 'median']])
# Out:
# Summary Statistics:
#                                        mean       max     median
# HDI Rank (2021)                  116.527027  191.0000  117.50000
# Life Expectancy at Birth (1990)   61.678976   76.6301   63.75835
# Life Expectancy at Birth (1991)   61.970728   76.5905   64.15725
# Life Expectancy at Birth (1992)   61.890578   76.6269   64.21250
# Life Expectancy at Birth (1993)   62.018374   76.7029   64.64135
# Life Expectancy at Birth (1994)   62.322742   76.6700   64.96315
# Life Expectancy at Birth (1995)   62.578247   76.5519   64.91715
# Life Expectancy at Birth (1996)   62.759663   76.8042   65.29655
# Life Expectancy at Birth (1997)   62.941059   77.2281   65.66315
# Life Expectancy at Birth (1998)   62.923286   77.9875   65.49565
# Life Expectancy at Birth (1999)   63.387561   78.4701   66.22450
# Life Expectancy at Birth (2000)   63.912529   79.0691   66.42510
# Life Expectancy at Birth (2001)   64.221391   79.1863   66.77215
# ...

# %%
 # Summary statistics for numerical each column
 print(life_expectancy_df.describe().T)
# Out:
#                                  count        mean        std      min  \
# HDI Rank (2021)                  148.0  116.527027  44.305748  12.0000
# Life Expectancy at Birth (1990)  148.0   61.678976   9.504520  29.9353
# Life Expectancy at Birth (1991)  148.0   61.970728   9.445871  30.1479
# Life Expectancy at Birth (1992)  148.0   61.890578   9.729283  22.7245
# Life Expectancy at Birth (1993)  148.0   62.018374   9.868665  22.7041
# Life Expectancy at Birth (1994)  148.0   62.322742   9.893914  14.0985
# Life Expectancy at Birth (1995)  148.0   62.578247   9.489707  30.9483
# Life Expectancy at Birth (1996)  148.0   62.759663   9.550536  31.2966
# Life Expectancy at Birth (1997)  148.0   62.941059   9.592469  32.2424
# Life Expectancy at Birth (1998)  148.0   62.923286  10.092738  18.3852
# Life Expectancy at Birth (1999)  148.0   63.387561   9.585534  42.0712
# Life Expectancy at Birth (2000)  148.0   63.912529   9.255190  44.5181
# ...

# %% [markdown]
# # This gives the Life Expectancy at Birth through 1990-2021 with the count of each year being 148.0 with the  mean, std, and min.

# %%
 # Summary statistics
print(life_expectancy_df.describe())
# Out:
#        HDI Rank (2021)  Life Expectancy at Birth (1990)  \
# count       148.000000                       148.000000
# mean        116.527027                        61.678976
# std          44.305748                         9.504520
# min          12.000000                        29.935300
# 25%          80.000000                        55.589275
# 50%         117.500000                        63.758350
# 75%         154.250000                        69.512825
# max         191.000000                        76.630100
#
#        Life Expectancy at Birth (1991)  Life Expectancy at Birth (1992)  \
# count                       148.000000                       148.000000
# mean                         61.970728                        61.890578
# std                           9.445871                         9.729283
# min                          30.147900                        22.724500
# 25%                          55.594475                        55.043375
# ...

# %%
# Display basic information about the dataset
print("Dataset Overview:")
print(life_expectancy_df.info())
# Provides column names, data types, and missing values
# Out:
# Dataset Overview:
# <class 'pandas.core.frame.DataFrame'>
# Index: 148 entries, 0 to 194
# Data columns (total 39 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ISO3                             148 non-null    object
#  1   Country                          148 non-null    object
#  2   Continent                        148 non-null    object
#  3   Hemisphere                       148 non-null    object
#  4   Human Development Groups         148 non-null    object
#  5   UNDP Developing Regions          148 non-null    object
#  6   HDI Rank (2021)                  148 non-null    float64
#  7   Life Expectancy at Birth (1990)  148 non-null    float64
#  8   Life Expectancy at Birth (1991)  148 non-null    float64
#  9   Life Expectancy at Birth (1992)  148 non-null    float64
#  10  Life Expectancy at Birth (1993)  148 non-null    float64
# ...

# %%
#Create a new dataframe for participants with depending on Continenet or Country and life expectancy at Birth at each year
#if continnent is africa and country is algeria
#show the life expectancy
df[(df['Continent'] == 'Africa') & (df['Country'] == 'Algeria')]
# Out:
#    ISO3  Country Continent           Hemisphere Human Development Groups  \
# 49  DZA  Algeria    Africa  Northern Hemisphere                     High
#
#    UNDP Developing Regions  HDI Rank (2021)  Life Expectancy at Birth (1990)  \
# 49                      AS             91.0                           67.416
#
#     Life Expectancy at Birth (1991)  Life Expectancy at Birth (1992)  ...  \
# 49                          67.6875                          67.7571  ...
#
#     Life Expectancy at Birth (2012)  Life Expectancy at Birth (2013)  \
# 49                          74.2024                          74.6153
#
#     Life Expectancy at Birth (2014)  Life Expectancy at Birth (2015)  \
# 49                            75.11                           75.622
#
#     Life Expectancy at Birth (2016)  Life Expectancy at Birth (2017)  \
# 49                          75.7318                          75.7428
#
#     Life Expectancy at Birth (2018)  Life Expectancy at Birth (2019)  \
# ...

# %% [markdown]
# According to my data, if a child was born in Africa in Algeria this the life expectancy at birth has increased since 1990 which was 67.4 to 2021 at 76.37

# %%
df[(df['Continent'] == 'Africa') & (df['Country'] == 'Algeria')] ['Life Expectancy at Birth (1990)']
# Out:
# 49    67.416
# Name: Life Expectancy at Birth (1990), dtype: float64

# %% [markdown]
# According to my data, if a child was born in African in Algeria there life Expectancy at Birth (1990) would be 67.416

# %%
df[(df['Continent'] == 'Asia') & (df['Country'] == 'China')] ['Life Expectancy at Birth (1999)']
# Out:
# 32    71.4188
# Name: Life Expectancy at Birth (1999), dtype: float64

# %% [markdown]
# According to my data, if a child was born in Asia, specifically China, in 1999, their life expectancy would be 71.4.

# %%
# Display the text in large, blue font
display(HTML('<h1 style="color:darkblue; font-size: 36px;">Data Visualization in project</h1>'))
# Out:
# <h1 style="color:darkblue; font-size: 36px;">Data Visualization in project</h1>

# %%
import pandas
import seaborn
from matplotlib import pyplot

# %%
# %config InlineBackend.figure_format = 'retina'
# "%"" telling the notebook this isnt code making the images look nice and crisp

# %%
seaborn.set_style('whitegrid')
#makes the background

# %%
df.shape
# Out:
# (195, 39)

# %%
#visualize the code
df.head()
# Out:
#   ISO3               Country Continent           Hemisphere  \
# 0  AFG           Afghanistan      Asia  Northern Hemisphere
# 1  AGO                Angola    Africa  Southern Hemisphere
# 2  ALB               Albania    Europe  Northern Hemisphere
# 3  AND               Andorra    Europe  Northern Hemisphere
# 4  ARE  United Arab Emirates      Asia  Northern Hemisphere
#
#   Human Development Groups UNDP Developing Regions  HDI Rank (2021)  \
# 0                      Low                      SA            180.0
# 1                   Medium                     SSA            148.0
# 2                     High                     ECA             67.0
# 3                Very High                     NaN             40.0
# 4                Very High                      AS             26.0
#
#    Life Expectancy at Birth (1990)  Life Expectancy at Birth (1991)  \
# 0                          45.9672                          46.6631
# ...

# %%
display(HTML('<h1 style="color:blue; font-size: 30px;">Summary statistics</h1>'))
# Out:
# <h1 style="color:blue; font-size: 30px;">Summary statistics</h1>

# %%
df.columns
# Out:
# Index(['ISO3', 'Country', 'Continent', 'Hemisphere',
#        'Human Development Groups', 'UNDP Developing Regions',
#        'HDI Rank (2021)', 'Life Expectancy at Birth (1990)',
#        'Life Expectancy at Birth (1991)', 'Life Expectancy at Birth (1992)',
#        'Life Expectancy at Birth (1993)', 'Life Expectancy at Birth (1994)',
#        'Life Expectancy at Birth (1995)', 'Life Expectancy at Birth (1996)',
#        'Life Expectancy at Birth (1997)', 'Life Expectancy at Birth (1998)',
#        'Life Expectancy at Birth (1999)', 'Life Expectancy at Birth (2000)',
#        'Life Expectancy at Birth (2001)', 'Life Expectancy at Birth (2002)',
#        'Life Expectancy at Birth (2003)', 'Life Expectancy at Birth (2004)',
#        'Life Expectancy at Birth (2005)', 'Life Expectancy at Birth (2006)',
#        'Life Expectancy at Birth (2007)', 'Life Expectancy at Birth (2008)',
#        'Life Expectancy at Birth (2009)', 'Life Expectancy at Birth (2010)',
# ...

# %%
# summary stat of HDI Rank (2021)
df['HDI Rank (2021)'].describe()
# Out:
# count    191.000000
# mean      95.811518
# std       55.307333
# min        1.000000
# 25%       48.500000
# 50%       96.000000
# 75%      143.500000
# max      191.000000
# Name: HDI Rank (2021), dtype: float64

# %%
#summary stat of life expectancy at birth
df['Life Expectancy at Birth (1990)'].describe()
# Out:
# count    195.000000
# mean      64.596583
# std       10.102225
# min       29.935300
# 25%       58.675500
# 50%       67.658400
# 75%       71.933450
# max       78.983800
# Name: Life Expectancy at Birth (1990), dtype: float64

# %%
#if mean and median are similar = data is nicely distributed

# %%
#Summary statistics of the 'life expectancy at birth 1990' column for each catergory of the 'country' column
df.groupby('Country')['Life Expectancy at Birth (1990)'].describe()
# Out:
#              count     mean  std      min      25%      50%      75%      max
# Country
# Afghanistan    1.0  45.9672  NaN  45.9672  45.9672  45.9672  45.9672  45.9672
# Albania        1.0  73.1439  NaN  73.1439  73.1439  73.1439  73.1439  73.1439
# Algeria        1.0  67.4160  NaN  67.4160  67.4160  67.4160  67.4160  67.4160
# Andorra        1.0  78.4063  NaN  78.4063  78.4063  78.4063  78.4063  78.4063
# Angola         1.0  41.8933  NaN  41.8933  41.8933  41.8933  41.8933  41.8933
# ...            ...      ...  ...      ...      ...      ...      ...      ...
# Venezuela      1.0  71.5319  NaN  71.5319  71.5319  71.5319  71.5319  71.5319
# Viet Nam       1.0  69.2127  NaN  69.2127  69.2127  69.2127  69.2127  69.2127
# Yemen          1.0  58.6994  NaN  58.6994  58.6994  58.6994  58.6994  58.6994
# Zambia         1.0  47.9263  NaN  47.9263  47.9263  47.9263  47.9263  47.9263
# Zimbabwe       1.0  59.4264  NaN  59.4264  59.4264  59.4264  59.4264  59.4264
#
# [195 rows x 8 columns]

# %%
df.groupby('Life Expectancy at Birth (2021)')['Human Development Groups'].describe()
# Out:
#                                 count unique        top freq
# Life Expectancy at Birth (2021)
# 52.5254                             1      1        Low    1
# 52.6760                             1      1        Low    1
# 53.0620                             1      1        Low    1
# 53.8947                             1      1        Low    1
# 54.9752                             1      1        Low    1
# ...                               ...    ...        ...  ...
# 83.9872                             1      1  Very High    1
# 84.5265                             1      1  Very High    1
# 84.7839                             1      1  Very High    1
# 85.4734                             1      1  Very High    1
# 85.9463                             0      0        NaN  NaN
#
# [195 rows x 4 columns]

# %% [markdown]
# #how many people died and had diabetes and how many people survied and had diabetes- change to my project

# %%
df.groupby('Life Expectancy at Birth (2021)')['UNDP Developing Regions'].describe()
# Out:
#                                 count unique  top freq
# Life Expectancy at Birth (2021)
# 52.5254                             1      1  SSA    1
# 52.6760                             1      1  SSA    1
# 53.0620                             1      1  SSA    1
# 53.8947                             1      1  SSA    1
# 54.9752                             1      1  SSA    1
# ...                               ...    ...  ...  ...
# 83.9872                             0      0  NaN  NaN
# 84.5265                             0      0  NaN  NaN
# 84.7839                             0      0  NaN  NaN
# 85.4734                             0      0  NaN  NaN
# 85.9463                             0      0  NaN  NaN
#
# [195 rows x 4 columns]

# %%
df.groupby('Life Expectancy at Birth (2021)')['HDI Rank (2021)'].describe()
# Out:
#                                  count   mean  std    min    25%    50%  \
# Life Expectancy at Birth (2021)
# 52.5254                            1.0  190.0  NaN  190.0  190.0  190.0
# 52.6760                            1.0  163.0  NaN  163.0  163.0  163.0
# 53.0620                            1.0  168.0  NaN  168.0  168.0  168.0
# 53.8947                            1.0  188.0  NaN  188.0  188.0  188.0
# 54.9752                            1.0  191.0  NaN  191.0  191.0  191.0
# ...                                ...    ...  ...    ...    ...    ...
# 83.9872                            1.0    1.0  NaN    1.0    1.0    1.0
# 84.5265                            1.0    5.0  NaN    5.0    5.0    5.0
# 84.7839                            1.0   19.0  NaN   19.0   19.0   19.0
# 85.4734                            1.0    4.0  NaN    4.0    4.0    4.0
# 85.9463                            0.0    NaN  NaN    NaN    NaN    NaN
#
#                                    75%    max
# ...

# %%
df.groupby('UNDP Developing Regions')['HDI Rank (2021)'].describe()
# Out:
#                          count        mean        std   min     25%    50%  \
# UNDP Developing Regions
# AS                        19.0   98.473684  48.730972  26.0   52.00  102.0
# EAP                       24.0  110.375000  37.118860  12.0   88.25  115.5
# ECA                       17.0   77.823529  21.783696  48.0   63.00   77.0
# LAC                       33.0   91.848485  29.176319  42.0   70.00   88.0
# SA                         9.0  123.444444  37.118429  73.0   90.00  129.0
# SSA                       46.0  157.847826  28.532996  63.0  146.50  164.0
#
#                             75%    max
# UNDP Developing Regions
# AS                       122.00  183.0
# EAP                      140.00  156.0
# ECA                       91.00  122.0
# LAC                      110.00  163.0
# SA                       143.00  180.0
# SSA                      177.75  191.0

# %% [markdown]
# explain each chart
# # now go through each column and compare if numerical, which one of the statics test will i do

# %%
display(HTML('<h1 style="color:blue; font-size: 30px;">Visulization</h1>'))
# Out:
# <h1 style="color:blue; font-size: 30px;">Visulization</h1>

# %% [markdown]
# ### Age vs Platelets

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=df,
    x='HDI Rank (2021)',
    y='Life Expectancy at Birth (2021)',
    hue='Continent',
    palette='Set2',
    s=100,
    edgecolor='black'
)
plt.title('HDI Rank vs Life Expectancy (2021)')
plt.xlabel('HDI Rank (Lower is Better)')
plt.ylabel('Life Expectancy (2021)')
plt.gca().invert_xaxis()  # HDI Rank: lower is better
plt.grid(True)
plt.show()

# %% [markdown]
#  HDI Rank vs. Life Expectancy (2021)

# %%
plt.figure(figsize=(10, 6))
sns.stripplot(
    data=df,
    x='Hemisphere',
    y='Life Expectancy at Birth (2021)',
    hue='Continent',
    dodge=True,
    jitter=True,
    alpha=0.7,
    palette='Dark2'
)
plt.title('Life Expectancy by Hemisphere')
plt.xlabel('Hemisphere')
plt.ylabel('Life Expectancy (2021)')
plt.grid(True)
plt.show()

# %% [markdown]
# Hemisphere vs. Life Expectancy (2021)

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=df,
    x='Life Expectancy at Birth (1990)',
    y='Life Expectancy at Birth (2021)',
    hue='Continent',
    style='Hemisphere',
    s=100
)
plt.plot([40, 90], [40, 90], '--', color='gray')  # identity line
plt.title('Life Expectancy: 1990 vs 2021')
plt.xlabel('Life Expectancy (1990)')
plt.ylabel('Life Expectancy (2021)')
plt.grid(True)
plt.show()

# %% [markdown]
# Life Expectancy Growth: 1990 vs 2021

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=df,
    x='HDI Rank (2021)',
    y='Life Expectancy at Birth (2021)',
    size='Life Expectancy at Birth (1990)',
    hue='Continent',
    sizes=(20, 300),
    alpha=0.8
)
plt.title('HDI Rank vs Life Expectancy (2021)\n(Bubble Size = 1990 Life Expectancy)')
plt.xlabel('HDI Rank')
plt.ylabel('Life Expectancy (2021)')
plt.gca().invert_xaxis()
plt.grid(True)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
#  HDI Rank vs Life Expectancy, Sized by 1990 Life Expectancy

# %%
seaborn.histplot(data=df, x='Life Expectancy at Birth (1990)', bins=range(30, 95, 10));

# %%
# create histrom life expectancy at birth (1999) from in 10s
seaborn.histplot(data=df, x='Life Expectancy at Birth (1999)', bins=range(30, 95, 10));

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load your dataset
df = pd.read_csv('/content/Life Expectancy at Birth.csv')  # Replace with your real file path if different

# %%
plt.figure(figsize=(10, 6))
sns.histplot(
    data=df,
    y='Life Expectancy at Birth (2021)',
    bins=20,
    color='skyblue'
)
plt.title('Life Expectancy at Birth (2021)')
plt.xlabel('Frequency')
plt.ylabel('Life Expectancy')
plt.tight_layout()
plt.show()

# %% [markdown]
# Horizontal Histogram

# %%
sns.displot(
    df,
    x='Life Expectancy at Birth (2021)',
    bins=15,
    hue='Continent',
    multiple='stack'
).set(
    title='Life Expectancy by Continent',
    xlabel='Life Expectancy at Birth (2021)',
    ylabel='Frequency'
)
plt.show()

# %% [markdown]
# Distribution Plots With hue by Continent

# %%
sns.displot(
    df,
    x='Life Expectancy at Birth (2021)',
    bins=15,
    col='Hemisphere'
).set(
    title='Life Expectancy by Hemisphere',
    xlabel='Life Expectancy at Birth (2021)',
    ylabel='Frequency'
)
plt.show()

# %% [markdown]
#  Distribution Split by Hemisphere

# %% [markdown]
# **2D Histograms and KDE**

# %%
sns.displot(
    df,
    x='Life Expectancy at Birth (2021)',
    y='Life Expectancy at Birth (1990)',
    cbar=True
).set(
    title='2021 vs 1990 Life Expectancy',
    xlabel='2021',
    ylabel='1990'
)
plt.show()

# %% [markdown]
# ## Histogram + Color Bar

# %%
sns.displot(
    df,
    x='Life Expectancy at Birth (2021)',
    y='Life Expectancy at Birth (1990)',
    kind='kde',
    rug=True
).set(
    title='KDE: 2021 vs 1990 Life Expectancy',
    xlabel='2021',
    ylabel='1990'
)
plt.show()

# %% [markdown]
# ## KDE + Rug

# %%
g = sns.JointGrid(
    data=df,
    x='Life Expectancy at Birth (2021)',
    y='Life Expectancy at Birth (1990)'
)
g.plot_joint(sns.histplot)
g.plot_marginals(sns.boxplot)
plt.show()

# %% [markdown]
# ## JointGrid Visualization

# %% [markdown]
# **Categorical Plots**

# %% [markdown]
# ## Boxen Plot

# %%
sns.catplot(
    data=df,
    x='Continent',
    y='Life Expectancy at Birth (2021)',
    hue='Hemisphere',
    kind='boxen'
).set(
    title='Life Expectancy by Continent and Hemisphere',
    xlabel='Continent',
    ylabel='Life Expectancy (2021)'
)
plt.show()

# %%
sns.catplot(
    data=df,
    x='Continent',
    y='Life Expectancy at Birth (2021)',
    hue='Hemisphere',
    kind='box'
).set(
    title='Box Plot: Life Expectancy (2021)',
    xlabel='Continent',
    ylabel='Life Expectancy'
)
plt.show()

# %% [markdown]
# ## Box Plot

# %%
sns.catplot(
    data=df,
    x='Continent',
    y='Life Expectancy at Birth (2021)',
    hue='Hemisphere',
    kind='violin'
).set(
    title='Violin Plot: Life Expectancy (2021)',
    xlabel='Continent',
    ylabel='Life Expectancy'
)
plt.show()

# %% [markdown]
# ## Violin Plot

# %%
sns.catplot(
    data=df,
    x='Continent',
    y='Life Expectancy at Birth (2021)',
    hue='Hemisphere',
    kind='violin',
    split=True
).set(
    title='Split Violin Plot: Life Expectancy (2021)',
    xlabel='Continent',
    ylabel='Life Expectancy'
)
plt.show()

# %% [markdown]
# ## Violin Plot Split

# %%
sns.catplot(
    data=df,
    x='Continent',
    y='Life Expectancy at Birth (2021)',
    hue='Hemisphere',
    kind='point'
).set(
    title='Point Plot: Life Expectancy (2021)',
    xlabel='Continent',
    ylabel='Life Expectancy'
)
plt.show()

# %% [markdown]
# ## Point Plot

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

sns.histplot(
    df['Life Expectancy at Birth (1990)'],
    bins=15,
    ax=ax1,
    color='coral'
)
ax1.set_title('Life Expectancy in 1990')
ax1.set_xlabel('Life Expectancy')
ax1.set_ylabel('Count')

sns.histplot(
    df['Life Expectancy at Birth (2021)'],
    bins=15,
    ax=ax2,
    color='seagreen'
)
ax2.set_title('Life Expectancy in 2021')
ax2.set_xlabel('Life Expectancy')
ax2.set_ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Subplots: Two Distribution Plots Side-by-Side

# %%
# Selecting only Life Expectancy columns
life_exp_cols = [col for col in df.columns if 'Life Expectancy' in col]
corr = df[life_exp_cols].corr()

plt.figure(figsize=(14, 10))
sns.heatmap(corr, cmap='coolwarm', annot=False)
plt.title('Correlation Heatmap of Life Expectancy (1990–2021)')
plt.show()

# %% [markdown]
# ## Heatmap of Correlations Between Life Expectancy Years

# %%
selected_years = [
    'Life Expectancy at Birth (1990)',
    'Life Expectancy at Birth (2000)',
    'Life Expectancy at Birth (2010)',
    'Life Expectancy at Birth (2021)'
]

sns.pairplot(df[selected_years])
plt.suptitle('Pair Plot of Life Expectancy Over Years', y=1.02)
plt.show()

# %% [markdown]
# ## Pair Plot: Explore Relationship Between Years

# %%
country = 'Ethiopia'  # change this to any country in your data

years = list(range(1990, 2022))
year_cols = [f'Life Expectancy at Birth ({year})' for year in years]

plt.figure(figsize=(12, 6))
plt.plot(years, df[df['Country'] == country][year_cols].values.flatten(), marker='o')
plt.title(f'Life Expectancy Over Time in {country}')
plt.xlabel('Year')
plt.ylabel('Life Expectancy')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Line Plot: Life Expectancy Over Time for One Country

# %%
top10 = df.sort_values(by='Life Expectancy at Birth (2021)', ascending=False).head(10)

plt.figure(figsize=(10, 6))
sns.barplot(
    data=top10,
    x='Life Expectancy at Birth (2021)',
    y='Country',
    palette='viridis'
)
plt.title('Top 10 Countries by Life Expectancy (2021)')
plt.xlabel('Life Expectancy')
plt.ylabel('Country')
plt.show()
# Out:
# <ipython-input-44-14c468aa9397>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# ## Top 10 Countries by Life Expectancy (2021)

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=df,
    x='HDI Rank (2021)',
    y='Life Expectancy at Birth (2021)',
    hue='Continent',
    palette='tab10'
)
plt.title('HDI Rank vs. Life Expectancy (2021)')
plt.xlabel('HDI Rank (Lower is Better)')
plt.ylabel('Life Expectancy')
plt.gca().invert_xaxis()  # HDI Rank: lower is better
plt.grid(True)
plt.show()

# %% [markdown]
#  Scatter Plot: HDI Rank vs. Life Expectancy (2021)

# %% [markdown]
# ## Heatmap of Correlation Between Numeric Features

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd # Import pandas

# Assuming your data is in 'Life Expectancy at Birth.csv'
life_expectancy_df = pd.read_csv('/content/Life Expectancy at Birth.csv') # Load the DataFrame

# Compute correlation matrix
corr = life_expectancy_df.corr(numeric_only=True)

# Create a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('🔍 Correlation Heatmap of Life Expectancy Features', fontsize=16)
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128269 (\N{LEFT-POINTING MAGNIFYING GLASS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# This heatmap shows how strongly different variables (e.g., GDP, literacy rate) are correlated with each other. Darker colors indicate stronger positive or negative relationships.
